# %%
import json
import pandas as pd
from collections import defaultdict
from pprint import pprint

# %%
def reformatJSON(file_name):
    # Open file
    with open(file_name, 'r') as f:
        data = json.load(f)

        reworked_data = defaultdict(list)
        park_dict = defaultdict(list)
        id = -1
        
        for instance in data['data']:
            id += 1
            for key in instance.keys():
                # Check if type is easy
                if isinstance(instance[key], str) or isinstance(instance[key], float): 
                    reworked_data[key].append(instance[key])

                # save parkCodes and states in dict so that things to do can be reformatted later
                elif key == 'relatedParks':
                    for d in instance[key]:
                        park_dict[id].append((d['states'], d['parkCode']))

                elif key == "tags":
                    reworked_data[key].append(','.join(instance[key]))

                elif isinstance(instance[key], list):
                    if key == 'activities' or key == 'topics' or 'key' == 'amenities':
                        # Join all into comma separated string
                        list_str = ', '.join(d['name'] for d in instance[key]) 
                        reworked_data[key].append(list_str)

        return reworked_data, park_dict

# %%
# Reformat the Park JSON file
reworked_park_data, _ = reformatJSON('Data/Parks.txt')
park_df = pd.DataFrame.from_dict(reworked_park_data)

# Reformat the Things to do JSON file
reworked_todo_data, park_dict = reformatJSON('Data/Things_to_do.txt')
temp_todo_df = pd.DataFrame.from_dict(reworked_todo_data)

# %%
# make a new rows so that each thing to do is associated with a single park
todo_df = pd.DataFrame(columns=list(temp_todo_df.columns).extend(['parkCode', 'states']))
for i in range(0, len(temp_todo_df)):
    for states, parkcode in park_dict[i]:
        new_row = temp_todo_df.iloc[i].copy()
        new_row['parkCode'] = parkcode
        new_row['states'] = states
        todo_df = pd.concat([todo_df, new_row.to_frame().T], ignore_index=True)

# %%
# Rename park datafram columns in preparation for merge
park_df.rename(columns={'url': 'park_url', 'fullName': 'park_name', 
                        'description': 'park_description', 'latitude': 'park_latitude',
                        'longitude': 'park_longitude','directionsInfo': 'park_directionsInfo', 
                        'directionsUrl': 'park_directionsUrl', 'weatherInfo': 'park_weatherInfo'},
                        inplace=True)

# %%
# Left join todo dataframe with park dataframe
park_activ_df = pd.merge(todo_df, park_df[['parkCode', 'park_url', 'park_name', 
                                           'park_description', 'park_latitude',
                                           'park_longitude','park_directionsInfo', 
                                            'park_directionsUrl', 'park_weatherInfo']],
                                            on = 'parkCode', how = 'left')

park_activ_df.head()
# Out:
#                                      id  \
# 0  83FB2FC0-EC43-4D0B-A29C-9C3EC1D3F89A
# 1  293841B3-F720-4872-BB59-214183BAF81E
# 2  8CDBCFD3-ADA7-4F47-B9F5-83F11223BABB
# 3  A32A8984-9383-4F06-928B-1757D520FFE7
# 4  C858429B-FCD7-430F-87CB-9AB47405F28C
#
#                                                  url  \
# 0  https://www.nps.gov/thingstodo/hike-cooper-roa...
# 1  https://www.nps.gov/thingstodo/hike-smokemont-...
# 2  https://www.nps.gov/thingstodo/hike-cove-hardw...
# 3  https://www.nps.gov/thingstodo/leconte-via-app...
# 4  https://www.nps.gov/thingstodo/charlies-bunion...
#
#                                                title  \
# 0                             Hike Cooper Road Trail
# 1                        Hike Smokemont Nature Trail
# 2                           Hike Cove Hardwood Trail
# 3  Hike to Mount Le Conte on the Appalachian Trai...
# 4                            Hike to Charlies Bunion
#
#                                     shortDescription  \
# 0  Hike 10.9 miles (17.5 km) one-way on Cooper Ro...
# 1  Hike 0.62-mile (1 km) roundtrip on Smokemont N...
# 2  Hike 0.75 miles (1.2 km) roundtrip on Cove Har...
# 3  The longest of the five routes to Mount Le Con...
# 4  Hike a popular section of the Appalachian Trai...
#
#                                                 tags            latitude  \
# 0                 hike,Cooper Road Trail,Cooper Road  35.610746646455034
# 1              hike,Smokemont,Smokemont Nature Trail   35.55791295835083
# 2  hike,chimneys picnic area,Cove Hardwood,Cove H...  35.636533121700516
# 3  Appalachian Trail,boulevard trail,le conte,Cha...       35.6112434302
# 4  Charlies Bunion,Appalachian Trail,hike,Mountai...       35.6112434302
#
#             longitude                         geometryPoiId  \
# 0  -83.93318327381866  166cdab3-554b-4409-b2f0-211650614ba0
# 1  -83.31234539082527  19b20900-10da-4c03-a944-cd7482ddbffa
# 2  -83.49219918251038
# 3      -83.4252812048  e8fc6a6b-597c-405e-8b5d-7012b36456c8
# 4      -83.4252812048  e8fc6a6b-597c-405e-8b5d-7012b36456c8
#
#                                             location seasonDescription  ...  \
# 0                                                                       ...
# 1                                                                       ...
# 2                                                                       ...
# 3  Expect crowds and full parking at Newfound Gap...                    ...
# 4  Expect full parking at Newfound Gap Overlook—c...                    ...
#
#   parkCode states                            park_url  \
# 0     grsm  NC,TN  https://www.nps.gov/grsm/index.htm
# 1     grsm  NC,TN  https://www.nps.gov/grsm/index.htm
# 2     grsm  NC,TN  https://www.nps.gov/grsm/index.htm
# 3     grsm  NC,TN  https://www.nps.gov/grsm/index.htm
# 4     grsm  NC,TN  https://www.nps.gov/grsm/index.htm
#
#                              park_name  \
# 0  Great Smoky Mountains National Park
# 1  Great Smoky Mountains National Park
# 2  Great Smoky Mountains National Park
# 3  Great Smoky Mountains National Park
# 4  Great Smoky Mountains National Park
#
#                                     park_description park_latitude  \
# 0  Ridge upon ridge of forest straddles the borde...   35.60116374
# 1  Ridge upon ridge of forest straddles the borde...   35.60116374
# 2  Ridge upon ridge of forest straddles the borde...   35.60116374
# 3  Ridge upon ridge of forest straddles the borde...   35.60116374
# 4  Ridge upon ridge of forest straddles the borde...   35.60116374
#
#   park_longitude                                park_directionsInfo  \
# 0   -83.50818326  Great Smoky Mountains National Park straddles ...
# 1   -83.50818326  Great Smoky Mountains National Park straddles ...
# 2   -83.50818326  Great Smoky Mountains National Park straddles ...
# 3   -83.50818326  Great Smoky Mountains National Park straddles ...
# 4   -83.50818326  Great Smoky Mountains National Park straddles ...
#
#                                   park_directionsUrl  \
# 0  http://www.nps.gov/grsm/planyourvisit/directio...
# 1  http://www.nps.gov/grsm/planyourvisit/directio...
# 2  http://www.nps.gov/grsm/planyourvisit/directio...
# 3  http://www.nps.gov/grsm/planyourvisit/directio...
# 4  http://www.nps.gov/grsm/planyourvisit/directio...
#
#                                     park_weatherInfo
# 0  Elevations in the park range from approximatel...
# 1  Elevations in the park range from approximatel...
# 2  Elevations in the park range from approximatel...
# 3  Elevations in the park range from approximatel...
# 4  Elevations in the park range from approximatel...
#
# [5 rows x 40 columns]

# %%
# Drop any metadata columns
columns_to_drop = ['id', 'geometryPoiId', 'credit', 'relevanceScore']

smaller_park_activ_df = park_activ_df.drop(columns=columns_to_drop)

smaller_park_activ_df.head()
# Out:
#                                                  url  \
# 0  https://www.nps.gov/thingstodo/hike-cooper-roa...
# 1  https://www.nps.gov/thingstodo/hike-smokemont-...
# 2  https://www.nps.gov/thingstodo/hike-cove-hardw...
# 3  https://www.nps.gov/thingstodo/leconte-via-app...
# 4  https://www.nps.gov/thingstodo/charlies-bunion...
#
#                                                title  \
# 0                             Hike Cooper Road Trail
# 1                        Hike Smokemont Nature Trail
# 2                           Hike Cove Hardwood Trail
# 3  Hike to Mount Le Conte on the Appalachian Trai...
# 4                            Hike to Charlies Bunion
#
#                                     shortDescription  \
# 0  Hike 10.9 miles (17.5 km) one-way on Cooper Ro...
# 1  Hike 0.62-mile (1 km) roundtrip on Smokemont N...
# 2  Hike 0.75 miles (1.2 km) roundtrip on Cove Har...
# 3  The longest of the five routes to Mount Le Con...
# 4  Hike a popular section of the Appalachian Trai...
#
#                                                 tags            latitude  \
# 0                 hike,Cooper Road Trail,Cooper Road  35.610746646455034
# 1              hike,Smokemont,Smokemont Nature Trail   35.55791295835083
# 2  hike,chimneys picnic area,Cove Hardwood,Cove H...  35.636533121700516
# 3  Appalachian Trail,boulevard trail,le conte,Cha...       35.6112434302
# 4  Charlies Bunion,Appalachian Trail,hike,Mountai...       35.6112434302
#
#             longitude                                           location  \
# 0  -83.93318327381866
# 1  -83.31234539082527
# 2  -83.49219918251038
# 3      -83.4252812048  Expect crowds and full parking at Newfound Gap...
# 4      -83.4252812048  Expect full parking at Newfound Gap Overlook—c...
#
#   seasonDescription                           accessibilityInformation  \
# 0                    <p>The first mile of this trail from the Abram...
# 1                    <p>No designated accessible parking spaces. Th...
# 2                    <p><a>Trail includes </a>some steep sections, ...
# 3                    <p>Trail is steep with occasional obstacles li...
# 4                    <p>Hike has many steep sections plus roots and...
#
#   isReservationRequired  ... parkCode states  \
# 0                 false  ...     grsm  NC,TN
# 1                 false  ...     grsm  NC,TN
# 2                 false  ...     grsm  NC,TN
# 3                 false  ...     grsm  NC,TN
# 4                 false  ...     grsm  NC,TN
#
#                              park_url                            park_name  \
# 0  https://www.nps.gov/grsm/index.htm  Great Smoky Mountains National Park
# 1  https://www.nps.gov/grsm/index.htm  Great Smoky Mountains National Park
# 2  https://www.nps.gov/grsm/index.htm  Great Smoky Mountains National Park
# 3  https://www.nps.gov/grsm/index.htm  Great Smoky Mountains National Park
# 4  https://www.nps.gov/grsm/index.htm  Great Smoky Mountains National Park
#
#                                     park_description park_latitude  \
# 0  Ridge upon ridge of forest straddles the borde...   35.60116374
# 1  Ridge upon ridge of forest straddles the borde...   35.60116374
# 2  Ridge upon ridge of forest straddles the borde...   35.60116374
# 3  Ridge upon ridge of forest straddles the borde...   35.60116374
# 4  Ridge upon ridge of forest straddles the borde...   35.60116374
#
#   park_longitude                                park_directionsInfo  \
# 0   -83.50818326  Great Smoky Mountains National Park straddles ...
# 1   -83.50818326  Great Smoky Mountains National Park straddles ...
# 2   -83.50818326  Great Smoky Mountains National Park straddles ...
# 3   -83.50818326  Great Smoky Mountains National Park straddles ...
# 4   -83.50818326  Great Smoky Mountains National Park straddles ...
#
#                                   park_directionsUrl  \
# 0  http://www.nps.gov/grsm/planyourvisit/directio...
# 1  http://www.nps.gov/grsm/planyourvisit/directio...
# 2  http://www.nps.gov/grsm/planyourvisit/directio...
# 3  http://www.nps.gov/grsm/planyourvisit/directio...
# 4  http://www.nps.gov/grsm/planyourvisit/directio...
#
#                                     park_weatherInfo
# 0  Elevations in the park range from approximatel...
# 1  Elevations in the park range from approximatel...
# 2  Elevations in the park range from approximatel...
# 3  Elevations in the park range from approximatel...
# 4  Elevations in the park range from approximatel...
#
# [5 rows x 36 columns]

# %%
# Save to csv
smaller_park_activ_df.to_csv('Data/Park Activities.csv')
