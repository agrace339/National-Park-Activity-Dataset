# %%
import urllib.request, json

# %%
def makeAPIcall(endpoint, file_name, api_key):
    # Make request with API key in header
    HEADERS = {"X-Api-Key":api_key}
    req = urllib.request.Request(endpoint,headers=HEADERS)
    
    with urllib.request.urlopen(req) as response:
        # Receive data as string
        response_data = response.read().decode('utf-8') 
        response_json = json.loads(response_data)

        # Data is saved as a txt file
        with open(f'Data/{file_name}', 'w') as f:
                json.dump(response_json, f, indent=4)
                print("Saved Data/{file_name}")

# %%
# To get your own API Key, go to 
# https://www.nps.gov/subjects/developer/api-documentation.htm
api_key = "" # Please add your API key here

# Get park data
makeAPIcall(endpoint="https://developer.nps.gov/api/v1/parks?limit=5000",
            file_name="Parks.txt", 
            api_key=api_key)

# Get activities data
makeAPIcall(endpoint="https://developer.nps.gov/api/v1/activities?limit=5000",
            file_name="Activities.txt", 
            api_key=api_key)

# Get things to do data
makeAPIcall(endpoint="https://developer.nps.gov/api/v1/thingstodo?limit=5000",
            file_name="Things_to_do.txt", 
            api_key=api_key)

# Get amenities data
makeAPIcall(endpoint="https://developer.nps.gov/api/v1/amenities?limit=5000",
            file_name="Amenities.txt", 
            api_key=api_key)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       1 #url can be changed by replacing '/parks' with another option listed on their documentation page
#       2 #https://www.nps.gov/subjects/developer/api-documentation.htm
#       3 api_key = "yEXBxl8XdvbyWURnrrmohO9GcYiY5wMLuTrHI2wN"
# ----> 5 makeAPIcall(endpoint="https://developer.nps.gov/api/v1/parks?limit=5000",
#       6             file_name="Parks.txt",
#       7             api_key=api_key)
#       9 makeAPIcall(endpoint="https://developer.nps.gov/api/v1/activities?limit=5000",
#      10             file_name="Activities.txt",
#      11             api_key=api_key)
#      13 makeAPIcall(endpoint="https://developer.nps.gov/api/v1/thingstodo?limit=5000",
#      14             file_name="Things_to_do.txt",
#      15             api_key=api_key)
#
# ...
